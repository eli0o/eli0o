# %% [markdown]
# <a href="https://colab.research.google.com/github/eli0o/eli0o/blob/main/Copy_of_pertemuan13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.__version__
# Out:
# '1.5.3'

# %%
data_kecelakaan = pd.Series(["Mobil","Motor","Pesawat","Kapal Laut"])
data_kecelakaan
# Out:
# 0         Mobil
# 1         Motor
# 2       Pesawat
# 3    Kapal Laut
# dtype: object

# %%
url = "https://raw.githubusercontent.com/project303/dataset/master/data-province-2015.cvs"

# %%
df = pd.read_csv(url, sep='\t')

# %%
df.describe()
# Out:
#           rainfall   rainy_day  expenses_food_urban  expenses_other_urban  \
# count    34.000000   34.000000            34.000000          3.400000e+01
# mean   1871.032353  144.382353        476174.176471          5.963873e+05
# std     716.155671   37.232289         81025.864223          1.415057e+05
# min     460.900000   68.000000        350517.000000          3.697460e+05
# 25%    1334.075000  124.750000        420900.000000          5.199162e+05
# 50%    1877.100000  143.500000        462096.000000          5.613845e+05
# 75%    2238.000000  166.750000        522762.000000          6.682235e+05
# max    3548.000000  218.000000        666922.000000          1.157945e+06
#
#        unemployment  time_zone
# count     34.000000  34.000000
# mean       5.980000   1.588235
# std        1.957125   0.701412
# min        1.990000   1.000000
# 25%        4.567500   1.000000
# 50%        5.685000   1.000000
# 75%        7.145000   2.000000
# max        9.930000   3.000000

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
dataFrame = pd.read_csv("drive/MyDrive/tahun2016.csv")
# Out:
# Mounted at /content/drive

# %%
dataFrame.describe()
# Out:
#         tahun      jumlah
# count  1068.0  801.000000
# mean   2016.0   44.624220
# std       0.0   57.230607
# min    2016.0    2.000000
# 25%    2016.0    9.000000
# 50%    2016.0   12.000000
# 75%    2016.0   79.000000
# max    2016.0  280.000000

# %%
dataFrame.hist("jumlah")
# Out:
# array([[<Axes: title={'center': 'jumlah'}>]], dtype=object)

# %%
dataFrame.hist("tahun")
# Out:
# array([[<Axes: title={'center': 'tahun'}>]], dtype=object)

# %%
dataFrame.head(11)
# Out:
#     tahun nama_kabupaten nama_kecamatan       nama_kelurahan  \
# 0    2016  JAKARTA PUSAT         Gambir               Gambir
# 1    2016  JAKARTA PUSAT         Gambir               Cideng
# 2    2016  JAKARTA PUSAT         Gambir         Petojo Utara
# 3    2016  JAKARTA PUSAT         Gambir       Petojo Selatan
# 4    2016  JAKARTA PUSAT         Gambir         Kebon Kelapa
# 5    2016  JAKARTA PUSAT         Gambir            Duri Pulo
# 6    2016  JAKARTA PUSAT    Sawah Besar           Pasar Baru
# 7    2016  JAKARTA PUSAT    Sawah Besar         Karang Anyar
# 8    2016  JAKARTA PUSAT    Sawah Besar              Kartini
# 9    2016  JAKARTA PUSAT    Sawah Besar  Gunung Sahari Utara
# 10   2016  JAKARTA PUSAT    Sawah Besar   Mangga Dua Selatan
#
#    nama_perangkat_desa_lembaga  jumlah
# 0               Rukun Tetangga    11.0
# 1               Rukun Tetangga   114.0
# 2               Rukun Tetangga   101.0
# 3               Rukun Tetangga    84.0
# ...

# %%
dataFrame.tail(11)
# Out:
#       tahun    nama_kabupaten            nama_kecamatan     nama_kelurahan  \
# 1057   2016     JAKARTA TIMUR                  Cipayung             Munjul
# 1058   2016     JAKARTA TIMUR                  Cipayung               Setu
# 1059   2016     JAKARTA TIMUR                  Cipayung         Bambu Apus
# 1060   2016     JAKARTA TIMUR                  Cipayung       Lubang Buaya
# 1061   2016     JAKARTA TIMUR                  Cipayung              Ceger
# 1062   2016  KEPULAUAN SERIBU    Kepulauan Seribu Utara     Pulau Panggang
# 1063   2016  KEPULAUAN SERIBU    Kepulauan Seribu Utara       Pulau Kelapa
# 1064   2016  KEPULAUAN SERIBU    Kepulauan Seribu Utara      Pulau Harapan
# 1065   2016  KEPULAUAN SERIBU  Kepulauan Seribu Selatan  Pulau Untung Jawa
# 1066   2016  KEPULAUAN SERIBU  Kepulauan Seribu Selatan       Pulau Tidung
# 1067   2016  KEPULAUAN SERIBU  Kepulauan Seribu Selatan         Pulau Pari
#
#      nama_perangkat_desa_lembaga  jumlah
# ...
